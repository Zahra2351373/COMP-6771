# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra2351373/COMP-6771/blob/Master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2
I = cv2.imread('I.jpg')
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
J = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.title('Color image ')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(J, cmap ='gray')
plt.title('Grayscale image')
plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()
