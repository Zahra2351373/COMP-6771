# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra2351373/COMP-6771/blob/Master/L2E2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# !ls
import cv2
cat = cv2.imread('cat.png')
from google.colab.patches import cv2_imshow
blue,green,red=cv2.split(cat)
img_gray=cv2.imread('cat.png',  cv2.IMREAD_GRAYSCALE)
cv2_imshow(red)
cv2_imshow(green)
cv2_imshow(blue)
# Out:
#      <input type="file" id="files-0692c813-70c1-478f-ad30-be09ff8bc2ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0692c813-70c1-478f-ad30-be09ff8bc2ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.png to cat (1).png
# 'cat (1).png'   cat.png   sample_data
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8AAA0BB6A0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8AAA024BE0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8AAA024BA8>
