# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra2351373/COMP-6771/blob/Master/L2E6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
I=cv2.imread('fruits.png')
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
noise = np.random.normal(0,1,I.size)
noise = noise.reshape(I.shape[0], I.shape[1], I.shape[2]).astype('uint8')
I_noisy = cv2.add(I,noise)
plt.figure()
plt.imshow(I)
plt.figure()
plt.imshow(I_noisy)
